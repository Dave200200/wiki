# %% [markdown]
# # Hallo kleiner Zwerg

# %% [markdown]
# ich habe dich lieb

# %% [markdown]
# ![weisst-du-eigentlich-wie-lieb-ich-dich-hab-gebundene-ausgabe-sam-mcbratney.jpeg](attachment:9eb04e94-9a4e-4d26-a5bc-f5d255135a50.jpeg)
